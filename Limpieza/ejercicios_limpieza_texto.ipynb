# %% [markdown]
# # Ejercicios: Limpieza de Texto
#
# ¡Es tu turno! Aplica lo aprendido para limpiar datos más complejos.
#
# ## Setup

# %%
# !pip install spacy -q
# !python -m spacy download es_core_news_sm
import spacy
import re
nlp = spacy.load("es_core_news_sm")

# %% [markdown]
# ## Ejercicio 1: Limpiador de Tweets
# Crea una función que elimine:
# 1. Hashtags (#)
# 2. Menciones (@usuario)
# 3. Emojis (pudes usar regex simple o una librería, intenta regex primero si puedes)

# %%
tweets = [
    "¡Increíble partido! #futbol #ganador @equipo",
    "No me gustó el servicio 😡 @servicio_cliente",
    "Oferta limitada en http://spam.com #oferta"
]

def limpiar_tweet(tweet):
    # TU CÓDIGO AQUÍ
    pass

# for t in tweets:
#     print(limpiar_tweet(t))

# %% [markdown]
# ## Ejercicio 2: Normalización de Productos
# Tienes una lista de productos mal escritos. Tu objetivo es normalizarlos para que "Iphone 12", "iPhone 12..", "iphone 12" sean lo mismo.

# %%
productos = ["Iphone 12", "iPhone 12..", "iphone 12", "Samsung s21!!", "SAMSUNG S21"]

def normalizar_producto(producto):
    # TU CÓDIGO AQUÍ
    pass

# Comprueba que al final la lista tenga elementos únicos reales
