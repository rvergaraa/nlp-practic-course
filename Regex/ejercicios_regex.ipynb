# %% [markdown]
# # Ejercicios Avanzados: Expresiones Regulares
#
# Tu misión es completar las 4 misiones de niveles incrementales.
#
# ## Setup

# %%
import re
import pandas as pd

# %% [markdown]
# ## Nivel 1: El Limpiador de Fechas
# Tienes un texto con fechas en formato `DD/MM/YYYY` o `DD-MM-YYYY`.
# **Objetivo**: Normalizar TODAS a `YYYY-MM-DD` usando `re.sub` y grupos.

# %%
texto_fechas = "Las facturas vensen el 31/01/2023, el 05-02-2023 y el 15/03/2023."

def normalizar_fechas(texto):
    # TU CÓDIGO AQUÍ: Usa re.sub con backreferences (ej: r"\3-\2-\1")
    return ""

# print(normalizar_fechas(texto_fechas))

# %% [markdown]
# ## Nivel 2: El Extractor de Logs (Named Groups)
# Extrae la IP, el Usuario (si existe, sino 'Anonimo') y el Mensaje.
# Nota: El usuario está entre corchetes `[user]` pero a veces no está.

# %%
logs = [
    "192.168.1.1 [admin] : Inició sesión correctamente",
    "10.0.0.1 : Error de conexión",
    "172.16.0.5 [invitado] : Timeout"
]

patron_log = r""" 
    # TU EXPRESION REGULAR AQUI (Usa re.VERBOSE)
"""

# for l in logs:
#    mach = re.search(patron_log, l, re.VERBOSE)
#    if mach: print(mach.groupdict())

# %% [markdown]
# ## Nivel 3: El Validador de Passwords (Lookarounds)
# Crea una regex que valide una contraseña solo si cumple TODO esto:
# 1. Al menos 8 caracteres.
# 2. Al menos una mayúscula.
# 3. Al menos un número.
# 4. NO contiene espacios.
#
# Tip: Usa varios Positive Lookaheads `(?=...)` al principio.

# %%
passwords = ["Abc12345", "password", "Abc 12345", "A1bcd", "MuySegura99"]

patron_password = r""" 
    # TU CÓDIGO AQUI
"""

# for p in passwords:
#     es_valida = bool(re.match(patron_password, p, re.VERBOSE))
#     print(f"{p}: {es_valida}")

# %% [markdown]
# ## Nivel 4: Data Obfuscation (Negative Lookbehind)
# Reemplaza la palabra "Secret" por "XXXX" solo si NO está precedida por "Top ".
# Es decir:
# - "Top Secret" -> Se queda igual.
# - "My Secret" -> "My XXXX"

# %%
textos = ["Este es un documento Top Secret del gobierno", "My Secret diary is here"]

patron_secreto = r"""
    # TU CÓDIGO AQUÍ
"""

# for t in textos:
#     print(re.sub(patron_secreto, "XXXX", t))
